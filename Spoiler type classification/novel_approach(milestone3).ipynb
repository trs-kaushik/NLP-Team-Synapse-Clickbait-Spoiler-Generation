# %%
import re
import pandas as pd
import json
import argparse
from os.path import exists
from glob import glob
from os.path import isdir
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import warnings
import nltk
warnings.simplefilter(action='ignore')
import spacy
from nltk.corpus import wordnet
from nltk import pos_tag

# %%
import pandas as pd
import json

def load_dataset(file_name):
    df = []
    with open(file_name) as f:
        for i in f:
            i = json.loads(i)
            label = i['tags']
            assert len(label) == 1
            label = label[0]
             
            if label not in ['phrase', 'phrases', 'passage', 'multi']:
                print(label)
                
            assert label in ['phrase', 'phrases', 'passage', 'multi']
            
            if label == 'multi':
                continue
            
            df += [{'postText': i['postText'],
                    'targetParagraphs': i['targetParagraphs'],
                    'targetTitle': i['targetTitle'],
                    'targetDescription': i['targetDescription'],
                    'targetKeywords': i['targetKeywords'],
                    'spoiler': i['spoiler'],
                     'labels': (label == 'phrase' or label == 'phrases')}]

    return pd.DataFrame(df)

# %%
train_dataset = load_dataset('/content/train.jsonl')
validation_dataset = load_dataset('/content/validation.jsonl')

# %%
train_dataset
# Out:
#                                                postText  \
# 0     [Wes Welker Wanted Dinner With Tom Brady, But ...
# 1      [NASA sets date for full recovery of ozone hole]
# 2     [This is what makes employees happy -- and it'...
# 3     [The perfect way to cook rice so that it's per...
# 4     [What happens if your new AirPods get lost or ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [Has Facebook's video explosion completely sha...
# 2638  [Cop Is Eating At A Chili's When Teen Hands Hi...
# 2639  [You need to see this Twitter account that pre...
# 2640       [GOP congressman comes out for gay marriage]
#
#                                        targetParagraphs  \
# 0     [It’ll be just like old times this weekend for...
# 1     [2070 is shaping up to be a great year for Mot...
# 2     [Despite common belief, money isn't the key to...
# 3     [Boiling rice may seem simple, but there is a ...
# 4     [One of the biggest surprise announcements at ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [A long time ago in a galaxy far, far away...W...
# 2638  [The Kansas City, Kansas Police Department are...
# 2639  [What the HELL?!, 1. Unless you’re somewhere w...
# 2640  [Rep. Charlie Dent (R-Pa.) came out in support...
#
#                                             targetTitle  \
# 0     Wes Welker Wanted Dinner With Tom Brady, But P...
# 1     Hole In Ozone Layer Expected To Make Full Reco...
# 2     Intellectual Stimulation Trumps Money For Empl...
# 3     Revealed: The perfect way to cook rice so that...
# 4     Here's what happens if your Apple AirPods get ...
# ...                                                 ...
# 2636  If You See A Purple Butterfly Sticker At The H...
# 2637  Facebook Video Surging, But YouTube Still Offe...
# 2638  Cop is eating at Chili's when teen hands him f...
# 2639  WTF, It Looks Like This Twitter Account "Predi...
# 2640  Pennsylvania GOP Rep. Charlie Dent Comes Out F...
#
#                                       targetDescription  \
# 0     It'll be just like old times this weekend for ...
# 1     2070 is shaping up to be a great year for Moth...
# 2     By: Chad Brooks \r\nPublished: 09/18/2013 06:4...
# 3     The question 'How does one cook rice properly?...
# 4     One of the first questions we had about Apple'...
# ...                                                 ...
# 2636  Millie found out she was pregnant and she and ...
# 2637                                                  .
# 2638                                               None
# 2639
# 2640                          Rep. Charlie Dent (R-Pa.)
#
#                                          targetKeywords  \
# 0       new england patriots, ricky doyle, top stories,
# 1     ozone layer,ozone hole determined by weather,M...
# 2     employee happiness money,employee happiness in...
# 3               Quora,users,share,perfect,way,cook,rice
# 4                                                  None
# ...                                                 ...
# 2636                                               None
# 2637           Facebook,web video,web video ads,YouTube
# 2638                                               None
# 2639
# 2640  lgbt,charlie dent gay marriage,Charlie Dent,pe...
#
#                                                 spoiler  labels
# 0                 [how about that morning we go throw?]   False
# 1                                                [2070]    True
# 2                            [intellectual stimulation]    True
# 3                                    [in a rice cooker]    True
# 4     [Apple says that if AirPods are lost or stolen...   False
# ...                                                 ...     ...
# 2636  [one of her unborn twins had a condition calle...   False
# 2637  [it hasn’t necessarily taken the wind out of Y...   False
# 2638           [It read, "Thanks for keeping us safe."]   False
# 2639                                   [@beyoncefan666]    True
# 2640                        [Rep. Charlie Dent (R-Pa.)]    True
#
# [2641 rows x 7 columns]

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
nlp = spacy.load("en_core_web_sm")
if not nlp.vocab:
    nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
def alter_nouns_with_synonyms(text):
    doc = nlp(text)
    result = []
    for token in doc:
        if token.pos_ == 'NOUN':
            synonyms = []
            for syn in wordnet.synsets(token.text):
                for lemma in syn.lemmas():
                    synonyms.append(lemma.name())
            if synonyms:
                changed = False
                for syn in synonyms:
                    if syn != token.text:
                        changed = True
                        result.append(syn)
                        break
                if not changed:
                    result.append(token.text)
            else:
                result.append(token.text)
        else:
            result.append(token.text)
    return ' '.join(result)

# %%
df_result = []
for i in range(len(train_dataset)):
    post_text = train_dataset.iloc[i]['postText'][0]
    altered_text = alter_nouns_with_synonyms(post_text)
    temp_res = {'postText': [altered_text],
                'targetParagraphs': train_dataset.iloc[i]['targetParagraphs'],
                'targetTitle': train_dataset.iloc[i]['targetTitle'],
                'targetDescription': train_dataset.iloc[i]['targetDescription'],
                'targetKeywords': train_dataset.iloc[i]['targetKeywords'],
                'spoiler': train_dataset.iloc[i]['spoiler'],
                'labels': train_dataset.iloc[i]['labels']}
    df_result.append(temp_res)

altered_dataframe = pd.DataFrame(df_result, columns=['postText', 'targetParagraphs',
                                                     'targetTitle', 'targetDescription',
                                                     'targetKeywords', 'spoiler',
                                                     'labels'])

# %%
altered_dataframe
# Out:
#                                                postText  \
# 0     [Wes Welker Wanted Dinner With Tom Brady , But...
# 1     [NASA sets day_of_the_month for full convalesc...
# 2     [This is what makes employee happy -- and it '...
# 3     [The perfect manner to cook Rice so that it 's...
# 4     [What happens if your new AirPods get lost or ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [Has Facebook 's picture detonation completely...
# 2638  [bull Is Eating At A Chili 's When Teen Hands ...
# 2639  [You need to see this Twitter history that pre...
# 2640    [GOP congresswoman comes out for gay matrimony]
#
#                                        targetParagraphs  \
# 0     [It’ll be just like old times this weekend for...
# 1     [2070 is shaping up to be a great year for Mot...
# 2     [Despite common belief, money isn't the key to...
# 3     [Boiling rice may seem simple, but there is a ...
# 4     [One of the biggest surprise announcements at ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [A long time ago in a galaxy far, far away...W...
# 2638  [The Kansas City, Kansas Police Department are...
# 2639  [What the HELL?!, 1. Unless you’re somewhere w...
# 2640  [Rep. Charlie Dent (R-Pa.) came out in support...
#
#                                             targetTitle  \
# 0     Wes Welker Wanted Dinner With Tom Brady, But P...
# 1     Hole In Ozone Layer Expected To Make Full Reco...
# 2     Intellectual Stimulation Trumps Money For Empl...
# 3     Revealed: The perfect way to cook rice so that...
# 4     Here's what happens if your Apple AirPods get ...
# ...                                                 ...
# 2636  If You See A Purple Butterfly Sticker At The H...
# 2637  Facebook Video Surging, But YouTube Still Offe...
# 2638  Cop is eating at Chili's when teen hands him f...
# 2639  WTF, It Looks Like This Twitter Account "Predi...
# 2640  Pennsylvania GOP Rep. Charlie Dent Comes Out F...
#
#                                       targetDescription  \
# 0     It'll be just like old times this weekend for ...
# 1     2070 is shaping up to be a great year for Moth...
# 2     By: Chad Brooks \r\nPublished: 09/18/2013 06:4...
# 3     The question 'How does one cook rice properly?...
# 4     One of the first questions we had about Apple'...
# ...                                                 ...
# 2636  Millie found out she was pregnant and she and ...
# 2637                                                  .
# 2638                                               None
# 2639
# 2640                          Rep. Charlie Dent (R-Pa.)
#
#                                          targetKeywords  \
# 0       new england patriots, ricky doyle, top stories,
# 1     ozone layer,ozone hole determined by weather,M...
# 2     employee happiness money,employee happiness in...
# 3               Quora,users,share,perfect,way,cook,rice
# 4                                                  None
# ...                                                 ...
# 2636                                               None
# 2637           Facebook,web video,web video ads,YouTube
# 2638                                               None
# 2639
# 2640  lgbt,charlie dent gay marriage,Charlie Dent,pe...
#
#                                                 spoiler  labels
# 0                 [how about that morning we go throw?]   False
# 1                                                [2070]    True
# 2                            [intellectual stimulation]    True
# 3                                    [in a rice cooker]    True
# 4     [Apple says that if AirPods are lost or stolen...   False
# ...                                                 ...     ...
# 2636  [one of her unborn twins had a condition calle...   False
# 2637  [it hasn’t necessarily taken the wind out of Y...   False
# 2638           [It read, "Thanks for keeping us safe."]   False
# 2639                                   [@beyoncefan666]    True
# 2640                        [Rep. Charlie Dent (R-Pa.)]    True
#
# [2641 rows x 7 columns]

# %%
datasets = [train_dataset, altered_dataframe]
result = pd.concat(datasets)

# %%
result
# Out:
#                                                postText  \
# 0     [Wes Welker Wanted Dinner With Tom Brady, But ...
# 1      [NASA sets date for full recovery of ozone hole]
# 2     [This is what makes employees happy -- and it'...
# 3     [The perfect way to cook rice so that it's per...
# 4     [What happens if your new AirPods get lost or ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [Has Facebook 's picture detonation completely...
# 2638  [bull Is Eating At A Chili 's When Teen Hands ...
# 2639  [You need to see this Twitter history that pre...
# 2640    [GOP congresswoman comes out for gay matrimony]
#
#                                        targetParagraphs  \
# 0     [It’ll be just like old times this weekend for...
# 1     [2070 is shaping up to be a great year for Mot...
# 2     [Despite common belief, money isn't the key to...
# 3     [Boiling rice may seem simple, but there is a ...
# 4     [One of the biggest surprise announcements at ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [A long time ago in a galaxy far, far away...W...
# 2638  [The Kansas City, Kansas Police Department are...
# 2639  [What the HELL?!, 1. Unless you’re somewhere w...
# 2640  [Rep. Charlie Dent (R-Pa.) came out in support...
#
#                                             targetTitle  \
# 0     Wes Welker Wanted Dinner With Tom Brady, But P...
# 1     Hole In Ozone Layer Expected To Make Full Reco...
# 2     Intellectual Stimulation Trumps Money For Empl...
# 3     Revealed: The perfect way to cook rice so that...
# 4     Here's what happens if your Apple AirPods get ...
# ...                                                 ...
# 2636  If You See A Purple Butterfly Sticker At The H...
# 2637  Facebook Video Surging, But YouTube Still Offe...
# 2638  Cop is eating at Chili's when teen hands him f...
# 2639  WTF, It Looks Like This Twitter Account "Predi...
# 2640  Pennsylvania GOP Rep. Charlie Dent Comes Out F...
#
#                                       targetDescription  \
# 0     It'll be just like old times this weekend for ...
# 1     2070 is shaping up to be a great year for Moth...
# 2     By: Chad Brooks \r\nPublished: 09/18/2013 06:4...
# 3     The question 'How does one cook rice properly?...
# 4     One of the first questions we had about Apple'...
# ...                                                 ...
# 2636  Millie found out she was pregnant and she and ...
# 2637                                                  .
# 2638                                               None
# 2639
# 2640                          Rep. Charlie Dent (R-Pa.)
#
#                                          targetKeywords  \
# 0       new england patriots, ricky doyle, top stories,
# 1     ozone layer,ozone hole determined by weather,M...
# 2     employee happiness money,employee happiness in...
# 3               Quora,users,share,perfect,way,cook,rice
# 4                                                  None
# ...                                                 ...
# 2636                                               None
# 2637           Facebook,web video,web video ads,YouTube
# 2638                                               None
# 2639
# 2640  lgbt,charlie dent gay marriage,Charlie Dent,pe...
#
#                                                 spoiler  labels
# 0                 [how about that morning we go throw?]   False
# 1                                                [2070]    True
# 2                            [intellectual stimulation]    True
# 3                                    [in a rice cooker]    True
# 4     [Apple says that if AirPods are lost or stolen...   False
# ...                                                 ...     ...
# 2636  [one of her unborn twins had a condition calle...   False
# 2637  [it hasn’t necessarily taken the wind out of Y...   False
# 2638           [It read, "Thanks for keeping us safe."]   False
# 2639                                   [@beyoncefan666]    True
# 2640                        [Rep. Charlie Dent (R-Pa.)]    True
#
# [5282 rows x 7 columns]

# %%
aug_data = result

# %%
aug_data
# Out:
#                                                postText  \
# 0     [Wes Welker Wanted Dinner With Tom Brady, But ...
# 1      [NASA sets date for full recovery of ozone hole]
# 2     [This is what makes employees happy -- and it'...
# 3     [The perfect way to cook rice so that it's per...
# 4     [What happens if your new AirPods get lost or ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [Has Facebook 's picture detonation completely...
# 2638  [bull Is Eating At A Chili 's When Teen Hands ...
# 2639  [You need to see this Twitter history that pre...
# 2640    [GOP congresswoman comes out for gay matrimony]
#
#                                        targetParagraphs  \
# 0     [It’ll be just like old times this weekend for...
# 1     [2070 is shaping up to be a great year for Mot...
# 2     [Despite common belief, money isn't the key to...
# 3     [Boiling rice may seem simple, but there is a ...
# 4     [One of the biggest surprise announcements at ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [A long time ago in a galaxy far, far away...W...
# 2638  [The Kansas City, Kansas Police Department are...
# 2639  [What the HELL?!, 1. Unless you’re somewhere w...
# 2640  [Rep. Charlie Dent (R-Pa.) came out in support...
#
#                                             targetTitle  \
# 0     Wes Welker Wanted Dinner With Tom Brady, But P...
# 1     Hole In Ozone Layer Expected To Make Full Reco...
# 2     Intellectual Stimulation Trumps Money For Empl...
# 3     Revealed: The perfect way to cook rice so that...
# 4     Here's what happens if your Apple AirPods get ...
# ...                                                 ...
# 2636  If You See A Purple Butterfly Sticker At The H...
# 2637  Facebook Video Surging, But YouTube Still Offe...
# 2638  Cop is eating at Chili's when teen hands him f...
# 2639  WTF, It Looks Like This Twitter Account "Predi...
# 2640  Pennsylvania GOP Rep. Charlie Dent Comes Out F...
#
#                                       targetDescription  \
# 0     It'll be just like old times this weekend for ...
# 1     2070 is shaping up to be a great year for Moth...
# 2     By: Chad Brooks \r\nPublished: 09/18/2013 06:4...
# 3     The question 'How does one cook rice properly?...
# 4     One of the first questions we had about Apple'...
# ...                                                 ...
# 2636  Millie found out she was pregnant and she and ...
# 2637                                                  .
# 2638                                               None
# 2639
# 2640                          Rep. Charlie Dent (R-Pa.)
#
#                                          targetKeywords  \
# 0       new england patriots, ricky doyle, top stories,
# 1     ozone layer,ozone hole determined by weather,M...
# 2     employee happiness money,employee happiness in...
# 3               Quora,users,share,perfect,way,cook,rice
# 4                                                  None
# ...                                                 ...
# 2636                                               None
# 2637           Facebook,web video,web video ads,YouTube
# 2638                                               None
# 2639
# 2640  lgbt,charlie dent gay marriage,Charlie Dent,pe...
#
#                                                 spoiler  labels
# 0                 [how about that morning we go throw?]   False
# 1                                                [2070]    True
# 2                            [intellectual stimulation]    True
# 3                                    [in a rice cooker]    True
# 4     [Apple says that if AirPods are lost or stolen...   False
# ...                                                 ...     ...
# 2636  [one of her unborn twins had a condition calle...   False
# 2637  [it hasn’t necessarily taken the wind out of Y...   False
# 2638           [It read, "Thanks for keeping us safe."]   False
# 2639                                   [@beyoncefan666]    True
# 2640                        [Rep. Charlie Dent (R-Pa.)]    True
#
# [5282 rows x 7 columns]

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB, GaussianNB
import re 
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
import nltk 
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def lemmit(row):
  lemm_list = []
  for text in row['postText']:
    doc = nlp(text)
    for word in doc:
      if not word.is_punct and not word.is_stop:
        lemm_list.append(word.lemma_)
    break
  return ' '.join(lemm_list)

# %%
aug_data['postText'] = aug_data.apply(lemmit, axis=1)

# %%
aug_data
# Out:
#                                                postText  \
# 0     Wes Welker want Dinner Tom Brady Patriots QB B...
# 1                     NASA set date recovery ozone hole
# 2                          make employee happy paycheck
# 3      perfect way cook rice perfectly fluffy stick pan
# 4                   happen new AirPods lose steal Apple
# ...                                                 ...
# 2636             Purple Butterfly Sticker Hospital mean
# 2637  Facebook picture detonation completely shake a...
# 2638  bull eat Chili Teen hand Folded Napkin walk aw...
# 2639     need Twitter history predict Beyoncé gestation
# 2640               GOP congresswoman come gay matrimony
#
#                                        targetParagraphs  \
# 0     [It’ll be just like old times this weekend for...
# 1     [2070 is shaping up to be a great year for Mot...
# 2     [Despite common belief, money isn't the key to...
# 3     [Boiling rice may seem simple, but there is a ...
# 4     [One of the biggest surprise announcements at ...
# ...                                                 ...
# 2636  [If You See A Purple Butterfly Sticker At The ...
# 2637  [A long time ago in a galaxy far, far away...W...
# 2638  [The Kansas City, Kansas Police Department are...
# 2639  [What the HELL?!, 1. Unless you’re somewhere w...
# 2640  [Rep. Charlie Dent (R-Pa.) came out in support...
#
#                                             targetTitle  \
# 0     Wes Welker Wanted Dinner With Tom Brady, But P...
# 1     Hole In Ozone Layer Expected To Make Full Reco...
# 2     Intellectual Stimulation Trumps Money For Empl...
# 3     Revealed: The perfect way to cook rice so that...
# 4     Here's what happens if your Apple AirPods get ...
# ...                                                 ...
# 2636  If You See A Purple Butterfly Sticker At The H...
# 2637  Facebook Video Surging, But YouTube Still Offe...
# 2638  Cop is eating at Chili's when teen hands him f...
# 2639  WTF, It Looks Like This Twitter Account "Predi...
# 2640  Pennsylvania GOP Rep. Charlie Dent Comes Out F...
#
#                                       targetDescription  \
# 0     It'll be just like old times this weekend for ...
# 1     2070 is shaping up to be a great year for Moth...
# 2     By: Chad Brooks \r\nPublished: 09/18/2013 06:4...
# 3     The question 'How does one cook rice properly?...
# 4     One of the first questions we had about Apple'...
# ...                                                 ...
# 2636  Millie found out she was pregnant and she and ...
# 2637                                                  .
# 2638                                               None
# 2639
# 2640                          Rep. Charlie Dent (R-Pa.)
#
#                                          targetKeywords  \
# 0       new england patriots, ricky doyle, top stories,
# 1     ozone layer,ozone hole determined by weather,M...
# 2     employee happiness money,employee happiness in...
# 3               Quora,users,share,perfect,way,cook,rice
# 4                                                  None
# ...                                                 ...
# 2636                                               None
# 2637           Facebook,web video,web video ads,YouTube
# 2638                                               None
# 2639
# 2640  lgbt,charlie dent gay marriage,Charlie Dent,pe...
#
#                                                 spoiler  labels
# 0                 [how about that morning we go throw?]   False
# 1                                                [2070]    True
# 2                            [intellectual stimulation]    True
# 3                                    [in a rice cooker]    True
# 4     [Apple says that if AirPods are lost or stolen...   False
# ...                                                 ...     ...
# 2636  [one of her unborn twins had a condition calle...   False
# 2637  [it hasn’t necessarily taken the wind out of Y...   False
# 2638           [It read, "Thanks for keeping us safe."]   False
# 2639                                   [@beyoncefan666]    True
# 2640                        [Rep. Charlie Dent (R-Pa.)]    True
#
# [5282 rows x 7 columns]

# %%
aug_data.dropna(inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
aug_data['labels'] = label_encoder.fit_transform(aug_data['labels'])

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split, KFold
X_train,X_test,y_train,y_test= train_test_split(aug_data.postText, aug_data.labels,test_size=0.3,random_state=42)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = TfidfVectorizer().fit(X_train)
X_train = vectorizer.transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

# %%
nb = MultinomialNB()
svm= SVC()
lr= LogisticRegression()

# %%
from sklearn.model_selection import RandomizedSearchCV
param_dist = {
    'C': np.logspace(-3, 3, 7),
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga'],
    'max_iter': [100, 500, 1000]
}

# %%
kfold = KFold(n_splits=10,shuffle=True,random_state=0)
random_search = RandomizedSearchCV(lr, param_distributions=param_dist, n_iter=10, cv=kfold, scoring='f1_weighted', verbose=1, random_state=42)
random_search.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# RandomizedSearchCV(cv=KFold(n_splits=10, random_state=0, shuffle=True),
#                    estimator=LogisticRegression(),
#                    param_distributions={'C': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02, 1.e+03]),
#                                         'max_iter': [100, 500, 1000],
#                                         'penalty': ['l1', 'l2'],
#                                         'solver': ['liblinear', 'saga']},
#                    random_state=42, scoring='f1_weighted', verbose=1)

# %%
#for one vs one classifier

lr_ovo = OneVsOneClassifier(lr)
lr_ovo.fit(X_train, y_train)

svm_ovo = OneVsOneClassifier(svm)
svm_ovo.fit(X_train,y_train)


nb_ovo = OneVsOneClassifier(nb)
nb_ovo.fit(X_train, y_train)
# Out:
# OneVsOneClassifier(estimator=MultinomialNB())

# %%
validation_dataset = load_dataset('/content/validation.jsonl')
validation_dataset['postText'] = validation_dataset.apply(lemmit, axis=1)
validation_dataset['labels'] = label_encoder.transform(validation_dataset['labels'])
X_val = validation_dataset['postText']
Y_val = validation_dataset['labels']
X_val = vectorizer.transform(X_val)
val_lr_ovo_pred = lr_ovo.predict(X_val)

# %%
validation_dataset.shape
# Out:
# (657, 7)

# %%
print("Best parameters: ", random_search.best_params_)
best_lr = random_search.best_estimator_
val_best_lr_pred = best_lr.predict(X_val)
# Out:
# Best parameters:  {'solver': 'liblinear', 'penalty': 'l2', 'max_iter': 1000, 'C': 100.0}

# %%
print("Tuned logistic regression ")
print(classification_report(Y_val,val_best_lr_pred))

cm_best_lr = confusion_matrix(Y_val, val_best_lr_pred)
tn_best_lr, fp_best_lr, fn_best_lr, tp_best_lr = cm_best_lr.ravel()
print("Tuned Logistic Regression:")
print(f"TP: {tp_best_lr}, TN: {tn_best_lr}, FP: {fp_best_lr}, FN: {fn_best_lr}")
# Out:
# Tuned logistic regression
#               precision    recall  f1-score   support
#
#            0       0.62      0.54      0.58       322
#            1       0.61      0.67      0.64       335
#
#     accuracy                           0.61       657
#    macro avg       0.61      0.61      0.61       657
# weighted avg       0.61      0.61      0.61       657
#
# Tuned Logistic Regression:
# TP: 226, TN: 175, FP: 147, FN: 109

# %%
print("one vs one logistic regression ")
print(classification_report(Y_val,val_lr_ovo_pred))

cm_lr_ovo = confusion_matrix(Y_val, val_lr_ovo_pred)
tn_lr_ovo, fp_lr_ovo, fn_lr_ovo, tp_lr_ovo = cm_lr_ovo.ravel()
print("One vs One Logistic Regression:")
print(f"TP: {tp_lr_ovo}, TN: {tn_lr_ovo}, FP: {fp_lr_ovo}, FN: {fn_lr_ovo}")
# Out:
# one vs one logistic regression
#               precision    recall  f1-score   support
#
#            0       0.63      0.46      0.53       322
#            1       0.59      0.73      0.65       335
#
#     accuracy                           0.60       657
#    macro avg       0.61      0.60      0.59       657
# weighted avg       0.61      0.60      0.59       657
#
# One vs One Logistic Regression:
# TP: 246, TN: 149, FP: 173, FN: 89

# %%
val_svm_ovo_pred = svm_ovo.predict(X_val)
print("one vs one SVM ")
print(classification_report(Y_val,val_svm_ovo_pred))

cm_svm_ovo = confusion_matrix(Y_val, val_svm_ovo_pred)
tn_svm_ovo, fp_svm_ovo, fn_svm_ovo, tp_svm_ovo = cm_svm_ovo.ravel()
print("One vs One SVM:")
print(f"TP: {tp_svm_ovo}, TN: {tn_svm_ovo}, FP: {fp_svm_ovo}, FN: {fn_svm_ovo}")
# Out:
# one vs one SVM
#               precision    recall  f1-score   support
#
#            0       0.62      0.47      0.53       322
#            1       0.59      0.73      0.65       335
#
#     accuracy                           0.60       657
#    macro avg       0.61      0.60      0.59       657
# weighted avg       0.61      0.60      0.59       657
#
# One vs One SVM:
# TP: 245, TN: 150, FP: 172, FN: 90

# %%
from scipy.stats import uniform, randint
param_dist_svm = {'C': uniform(loc=1, scale=10),
              'gamma': uniform(loc=0.01, scale=0.1),
              'kernel': ['linear', 'rbf']}
random_search_svm = RandomizedSearchCV(SVC(), param_dist_svm, refit=True, verbose=2, scoring='f1_weighted', cv=kfold, n_iter=20)
random_search_svm.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.4s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=2.756780775825261, gamma=0.09017758861139104, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.4s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=9.329092648978456, gamma=0.07878668053690768, kernel=linear; total time=   0.5s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.5s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.7s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.6s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.6s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.6s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.5s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.5s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.5s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.4s
# [CV] END C=7.710894083026258, gamma=0.07744518827702868, kernel=rbf; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.6s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=9.411887441125854, gamma=0.03954162539896984, kernel=linear; total time=   0.5s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.4s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.4s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.4s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.4s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.4s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.4s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.5s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.6s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.6s
# [CV] END C=1.6300697126563504, gamma=0.0807744662596617, kernel=rbf; total time=   0.5s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.5s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.5s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.8s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.8s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.7s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.8s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.8s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   1.0s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.9s
# [CV] END C=1.0327282113570337, gamma=0.06495999086686238, kernel=linear; total time=   0.9s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.4s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.4s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.4s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.4s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.4s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.4s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.4s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.5s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.6s
# [CV] END C=1.2171391041904136, gamma=0.033764180697388596, kernel=rbf; total time=   0.6s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.6s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.7s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.6s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.5s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.5s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.5s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.5s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.5s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.5s
# [CV] END C=10.893176768789035, gamma=0.07122757018940985, kernel=rbf; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=7.194795204939614, gamma=0.028137601822202457, kernel=linear; total time=   0.5s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.5s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.4s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.4s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.6s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.5s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.6s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.6s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.6s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.5s
# [CV] END C=1.937677826780855, gamma=0.06558749281160159, kernel=linear; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=4.014233261704671, gamma=0.02015179373713684, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=1.2294568742043257, gamma=0.10640576153081165, kernel=rbf; total time=   0.4s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.4s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.5s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.6s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.6s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.6s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.6s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.6s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.4s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.4s
# [CV] END C=3.180605567782641, gamma=0.03828973259285249, kernel=rbf; total time=   0.4s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.4s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.4s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.5s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.5s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.5s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.5s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.4s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.5s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.5s
# [CV] END C=4.0889401034719235, gamma=0.10877991870047514, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.5s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.7s
# [CV] END C=10.993842476648325, gamma=0.04021682696353682, kernel=linear; total time=   0.6s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.6s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.6s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.6s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.4s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.4s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.4s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.4s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.4s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.4s
# [CV] END C=3.7917528125590305, gamma=0.021582163816355887, kernel=rbf; total time=   0.4s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.6s
# [CV] END C=3.563282920648221, gamma=0.03825192650189275, kernel=linear; total time=   0.5s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.4s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.5s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.5s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.5s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.6s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.7s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.6s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.7s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.6s
# [CV] END C=8.67017449628893, gamma=0.06769504823399895, kernel=linear; total time=   0.5s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.5s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.5s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.4s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.5s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.4s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.4s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.4s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.5s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.5s
# [CV] END C=2.2556287838833393, gamma=0.07190172216053109, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.4s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# [CV] END C=4.176984340549507, gamma=0.038031752050910146, kernel=linear; total time=   0.5s
# RandomizedSearchCV(cv=KFold(n_splits=10, random_state=0, shuffle=True),
#                    estimator=SVC(), n_iter=20,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f0338809990>,
#                                         'gamma': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f032e29ae90>,
#                                         'kernel': ['linear', 'rbf']},
#                    scoring='f1_weighted', verbose=2)

# %%
best_params_svm = random_search_svm.best_params_
print(" hyperparameters ", best_params_svm)
# Out:
# Best hyperparameters found:  {'C': 8.67017449628893, 'gamma': 0.06769504823399895, 'kernel': 'linear'}

# %%
svm_best = SVC(**best_params_svm)
svm_best.fit(X_train, y_train)
val_svm_best_pred = svm_best.predict(X_val)
print("tuned svm")
print(classification_report(Y_val, val_svm_best_pred))

cm_svm_best = confusion_matrix(Y_val, val_svm_best_pred)
tn_svm_best, fp_svm_best, fn_svm_best, tp_svm_best = cm_svm_best.ravel()
print(f"TP: {tp_svm_best}, TN: {tn_svm_best}, FP: {fp_svm_best}, FN: {fn_svm_best}")
# Out:
# tuned svm
#               precision    recall  f1-score   support
#
#            0       0.60      0.53      0.56       322
#            1       0.59      0.65      0.62       335
#
#     accuracy                           0.60       657
#    macro avg       0.60      0.59      0.59       657
# weighted avg       0.60      0.60      0.59       657
#
# Tuned SVM:
# TP: 219, TN: 172, FP: 150, FN: 116

# %%
len(val_svm_best_pred)
# Out:
# 657

# %%
val_nb_ovo_pred = nb_ovo.predict(X_val)
print("one vs one nb ")
print(classification_report(Y_val,val_nb_ovo_pred))

cm_nb_ovo = confusion_matrix(Y_val, val_nb_ovo_pred)
tn_nb_ovo, fp_nb_ovo, fn_nb_ovo, tp_nb_ovo = cm_nb_ovo.ravel()
print("One vs One Naive Bayes:")
print(f"TP: {tp_nb_ovo}, TN: {tn_nb_ovo}, FP: {fp_nb_ovo}, FN: {fn_nb_ovo}")
# Out:
# one vs one nb
#               precision    recall  f1-score   support
#
#            0       0.59      0.44      0.51       322
#            1       0.57      0.71      0.63       335
#
#     accuracy                           0.58       657
#    macro avg       0.58      0.58      0.57       657
# weighted avg       0.58      0.58      0.57       657
#
# One vs One Naive Bayes:
# TP: 238, TN: 142, FP: 180, FN: 97

# %%
from scipy.stats import uniform
param_dist_nb = {'alpha': uniform(loc=0.1, scale=0.9)}
random_search_nb = RandomizedSearchCV(nb, param_dist_nb, n_iter=20, scoring='f1_weighted', cv=kfold)
random_search_nb.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=10, random_state=0, shuffle=True),
#                    estimator=MultinomialNB(), n_iter=20,
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7f0338aafa00>},
#                    scoring='f1_weighted')

# %%
best_params_nb = random_search_nb.best_params_

nb_best = MultinomialNB(alpha=best_params_nb['alpha'])
nb_best.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=0.11147125145059127)

# %%
val_nb_best_pred = nb_best.predict(X_val)
print("Multinomial NB with hyperparameters")
print(classification_report(Y_val, val_nb_best_pred))

cm_nb_best = confusion_matrix(Y_val, val_nb_best_pred)
tn_nb_best, fp_nb_best, fn_nb_best, tp_nb_best = cm_nb_best.ravel()
print(f"TP: {tp_nb_best}, TN: {tn_nb_best}, FP: {fp_nb_best}, FN: {fn_nb_best}")
# Out:
# Multinomial NB with hyperparameters
#               precision    recall  f1-score   support
#
#            0       0.58      0.47      0.52       322
#            1       0.57      0.67      0.61       335
#
#     accuracy                           0.57       657
#    macro avg       0.57      0.57      0.57       657
# weighted avg       0.57      0.57      0.57       657
#
# Tuned Naive Bayes:
# TP: 224, TN: 152, FP: 170, FN: 111
